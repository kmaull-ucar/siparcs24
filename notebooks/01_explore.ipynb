# %%
import pandas as pd

# %%
pd.read_csv("../data/2023-09-26_2023-10-10_raw_data_NEON_RMNP_iotwx.csv", skiprows=18)
# Out:
#                        Time  Temperature  UVAB   Humidity  Pressure  \
# 0      2023-09-26T00:05:30Z    12.195221   NaN        NaN       NaN
# 1      2023-09-26T00:05:31Z          NaN   NaN        NaN   73853.0
# 2      2023-09-26T00:05:32Z          NaN   NaN  37.202045       NaN
# 3      2023-09-26T00:05:33Z          NaN   NaN        NaN       NaN
# 4      2023-09-26T00:05:37Z          NaN   NaN        NaN       NaN
# ...                     ...          ...   ...        ...       ...
# 35083  2023-10-09T23:53:10Z          NaN   NaN        NaN       NaN
# 35084  2023-10-09T23:53:11Z          NaN   NaN        NaN       NaN
# 35085  2023-10-09T23:53:13Z          NaN   NaN        NaN       NaN
# 35086  2023-10-09T23:53:26Z          NaN   NaN        NaN       NaN
# 35087  2023-10-09T23:53:29Z          NaN   NaN        NaN       NaN
#
#        VOC (aggregate)  Precipitation  Precipitation Rate  PM2.5  PM10  PM1.0  \
# ...

# %% [markdown]
# Have fun!
